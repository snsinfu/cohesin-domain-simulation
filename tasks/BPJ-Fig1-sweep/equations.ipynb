# %%
import matplotlib.pyplot as plt
import numpy as np

from lib.plots import set_axis

# %%
fig, ax = plt.subplots()

s = "\n".join([
    r"$ -\varepsilon_\mathrm{assoc} $",
    r"$ \varepsilon_\mathrm{assoc} = 5 \, k_\mathrm{B} T $",
    r"$ \sigma $",
    r"$ \sigma_\mathrm{assoc} $",
])
ax.text(0, 0, s, usetex=True)

set_axis(ax, "none")
fig.savefig("_figs/equations.svg")

pass
